# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
## from google.colab import drive
## drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
# Defining the path for train and test images from the local system.
data_dir_train = pathlib.Path("C:\\Users\\hp\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train")
data_dir_test  = pathlib.Path("C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Test")

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
###The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of 
#shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor 
#of the shape `(32,)`, these are corresponding labels to the 32 images.

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
# Count the number of image in Train and Test directory
# Using the glob to retrieve files/pathnames matching a specified pattern.

#Train Image count
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)

#Test Image count
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %%
#Visualize one instance of all the class present in the dataset.
from tensorflow.keras.preprocessing.image import load_img
#image_dataset_from_directory() will return a tf.data.Dataset that yields batches of images from the subdirectories.
#label_mode is categorial, the labels are a float32 tensor of shape (batch_size, num_classes), representing a one-hot encoding of the class index.
image_dataset = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=32,image_size=(180,180),
                                                                    label_mode='categorical',seed=123)

#all the classes of Skin Cancer
class_names = image_dataset.class_names

#Dictionary to store the path of image as per the class
files_path_dict = {}

for c in class_names:
    files_path_dict[c] = list(map(lambda x:str(data_dir_train)+'/'+c+'/'+x,os.listdir(str(data_dir_train)+'/'+c)))
    
#Visualize image 
plt.figure(figsize=(15,15))
index = 0
for c in class_names:
    path_list = files_path_dict[c][:1]
    index += 1
    plt.subplot(3,3,index)
    plt.imshow(load_img(path_list[0],target_size=(180,180)))
    plt.title(c)
    plt.axis("off")
# Out:
# Found 2239 files belonging to 9 classes.

# %%
def class_distribution_count(directory):
    
    #count number of image in each classes
    count= []
    for path in pathlib.Path(directory).iterdir():
        if path.is_dir():
            count.append(len([name for name in os.listdir(path)
                               if os.path.isfile(os.path.join(path, name))]))
    
    #name of the classes
    sub_directory = [name for name in os.listdir(directory)
                    if os.path.isdir(os.path.join(directory, name))]
    
    #return dataframe with image count and class.
    return pd.DataFrame(list(zip(sub_directory,count)),columns =['Class', 'No. of Image'])

df = class_distribution_count(data_dir_train)
df
# Out:
#                         Class  No. of Image
# 0           actinic keratosis           114
# 1        basal cell carcinoma           376
# 2              dermatofibroma            95
# 3                    melanoma           438
# 4                       nevus           357
# 5  pigmented benign keratosis           462
# 6        seborrheic keratosis            77
# 7     squamous cell carcinoma           181
# 8             vascular lesion           139

# %%
#Visualize the Number of image in each class.
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.barplot(x="No. of Image", y="Class", data=df,
            label="Class")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 import seaborn as sns
#       3 plt.figure(figsize=(10, 8))
# ----> 4 sns.barplot(x="No. of Image", y="Class", data=df,
#       5             label="Class")
#
# NameError: name 'df' is not defined

# %%
#install Augmentor
# !pip install Augmentor
# Out:
# Requirement already satisfied: Augmentor in c:\users\hp\anaconda3\lib\site-packages (0.2.12)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\hp\anaconda3\lib\site-packages (from Augmentor) (10.0.1)
# Requirement already satisfied: tqdm>=4.9.0 in c:\users\hp\anaconda3\lib\site-packages (from Augmentor) (4.65.0)
# Requirement already satisfied: numpy>=1.11.0 in c:\users\hp\anaconda3\lib\site-packages (from Augmentor) (1.24.3)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm>=4.9.0->Augmentor) (0.4.6)

# %%
# Iterate through each class
import Augmentor
path_to_training_dataset=data_dir_train

for class_name in class_names:
    p = Augmentor.Pipeline((path_to_training_dataset / class_name).as_posix())
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500)

# %%
#Count total number of image generated by Augmentor.
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 0

# %%
# train dataset 
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset

train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train, batch_size=32,
                                                               image_size=(180,180), label_mode='categorical',
                                                               seed=123,subset="training",
                                                               validation_split=0.2)

#label_mode is categorial, the labels are a float32 tensor of shape (batch_size, num_classes),
#representing a one-hot encoding of the class index.
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
# validation dataset 
val_ds =tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=32,
                                                            image_size=(180,180), label_mode='categorical',
                                                            seed=123,subset="validation",
                                                            validation_split=0.2)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %%
#tf.data.experimental.AUTOTUNE defines appropriate number of processes that are free for working.

#`Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.

#`Dataset.prefetch()` overlaps data preprocessing and model execution while training.


AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
### Your code goes here
num_classes = 9

#A Sequential model is appropriate for a plain stack of layers where each layer has exactly one input tensor and one output tensor
model = Sequential([
  #layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Rescaling(1./255, input_shape=(180, 180, 3)),

  #2D convolution layer (e.g. spatial convolution over images).
  layers.Conv2D(16, 3, padding='same', activation='relu'),

  #We slide over the feature map and extract tiles of a specified size.
  #Downsamples the input along its spatial dimensions (height and width) by taking the maximum value over an input window (of size defined by pool_size) for each channel of the input.
  layers.MaxPooling2D(),

  #We slide over the feature map and extract tiles of a specified size.
  layers.Conv2D(32, 3, padding='same', activation='relu'),

  layers.MaxPooling2D(),

  layers.Conv2D(64, 3, padding='same', activation='relu'),

  #We slide over the feature map and extract tiles of a specified size.
  #Advantages of downsampling - Decreased size of input for upcoming layers, Works against overfitting
  layers.MaxPooling2D(),

  #Flattening - Convert into 1D feature vector.  Flattens all its structure to create a single long feature vector
  ##Flattens the input. Does not affect the batch size.
  layers.Flatten(),

  #fully connected layer
  #A hidden layer in which each node is connected to every node in the subsequent hidden layer.
  #A fully connected layer is also known as a dense layer.

  layers.Dense(128, activation='relu'),

  #Dense is the only actual network layer in that model. A Dense layer feeds all outputs from the previous layer to all its neurons, each neuron providing one output to the next layer.
  #It's the most basic layer in neural networks. A Dense(10) has ten neurons. A Dense(512) has 512 neurons.
  #Dense implements the operation: output = activation(dot(input, kernel)
  #Dense Layer - A dense layer represents a matrix vector multiplication.  each input node is connected to each output node.
  layers.Dense(num_classes)
  #Dense Layer - A dense layer represents a matrix vector multiplication.  each input node is connected to each output node.
])
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:18: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 180, 180, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 90, 90, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 90, 90, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 45, 45, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 45, 45, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 22, 22, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 30976)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     3,965,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 9)              │         1,161 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,989,801 (15.22 MB)
#  Trainable params: 3,989,801 (15.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
### Todo, choose an appropirate optimiser and loss function
#RMSprop. RMSprop is a very effective, but currently unpublished adaptive learning rate method
#Adam. Adam is a recently proposed update that looks a bit like RMSProp with momentum. The (simplified) update looks as follows:
#model.compile(optimizer='adam',
#              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#              metrics=['accuracy'])
model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 17s 227ms/step - accuracy: 0.1369 - loss: 3.0300 - val_accuracy: 0.2058 - val_loss: 2.0264
# Epoch 2/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 206ms/step - accuracy: 0.2111 - loss: 2.0181 - val_accuracy: 0.2953 - val_loss: 2.0031
# Epoch 3/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 211ms/step - accuracy: 0.2515 - loss: 4.2120 - val_accuracy: 0.1790 - val_loss: 4.4032
# Epoch 4/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 211ms/step - accuracy: 0.1635 - loss: 4.2600 - val_accuracy: 0.1790 - val_loss: 4.4032
# Epoch 5/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.1580 - loss: 4.2656 - val_accuracy: 0.1790 - val_loss: 4.4032
# Epoch 6/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 207ms/step - accuracy: 0.1436 - loss: 4.6375 - val_accuracy: 0.1790 - val_loss: 4.4032
# Epoch 7/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.1558 - loss: 4.4252 - val_accuracy: 0.1790 - val_loss: 4.4032
# Epoch 8/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 211ms/step - accuracy: 0.1593 - loss: 4.3018 - val_accuracy: 0.1790 - val_loss: 4.4032
# Epoch 9/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 207ms/step - accuracy: 0.1596 - loss: 4.3376 - val_accuracy: 0.1790 - val_loss: 4.4032
# Epoch 10/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 214ms/step - accuracy: 0.1575 - loss: 4.2751 - val_accuracy: 0.1790 - val_loss: 4.4032
# Epoch 11/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 219ms/step - accuracy: 0.1674 - loss: 4.2909 - val_accuracy: 0.1790 - val_loss: 4.4032
# Epoch 12/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 234ms/step - accuracy: 0.1720 - loss: 4.2379 - val_accuracy: 0.1790 - val_loss: 4.4032
# Epoch 13/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 238ms/step - accuracy: 0.1640 - loss: 4.0829 - val_accuracy: 0.1790 - val_loss: 4.4032
# Epoch 14/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 219ms/step - accuracy: 0.1527 - loss: 4.3095 - val_accuracy: 0.1790 - val_loss: 4.4032
# Epoch 15/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - accuracy: 0.1503 - loss: 4.4824 - val_accuracy: 0.1790 - val_loss: 4.4032
# Epoch 16/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 220ms/step - accuracy: 0.1586 - loss: 4.1900 - val_accuracy: 0.1790 - val_loss: 4.4032
# Epoch 17/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 219ms/step - accuracy: 0.1555 - loss: 4.1644 - val_accuracy: 0.1790 - val_loss: 4.4032
# Epoch 18/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 218ms/step - accuracy: 0.1531 - loss: 4.6696 - val_accuracy: 0.1790 - val_loss: 4.4032
# Epoch 19/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - accuracy: 0.1601 - loss: 4.5371 - val_accuracy: 0.1790 - val_loss: 4.4032
# Epoch 20/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 228ms/step - accuracy: 0.1598 - loss: 3.9739 - val_accuracy: 0.1790 - val_loss: 4.4032

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
### your code goes here, you can use training or validation data to visualize

# %%
### Your code goes here
num_classes = 9

model = Sequential([
  #layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    layers.Rescaling(1./255, input_shape=(180, 180, 3)),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  #We slide over the feature map and extract tiles of a specified size.
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  #We slide over the feature map and extract tiles of a specified size.
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  #We slide over the feature map and extract tiles of a specified size.
  layers.MaxPooling2D(),
  #Advantages of downsampling - Decreased size of input for upcoming layers, Works against overfitting
  layers.Flatten(),
  #Flattening - Convert into 1D feature vector.  Flattens all its structure to create a single long feature vector
  layers.Dense(128, activation='relu'),
  #Dense Layer - A dense layer represents a matrix vector multiplication.  each input node is connected to each output node.
  layers.Dense(num_classes)
  #Dense Layer - A dense layer represents a matrix vector multiplication.  each input node is connected to each output node.
])
model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.1567 - loss: 10.9451 - val_accuracy: 0.1499 - val_loss: 13.1958
# Epoch 2/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.1747 - loss: 13.1093 - val_accuracy: 0.1499 - val_loss: 13.1958
# Epoch 3/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.1662 - loss: 12.9232 - val_accuracy: 0.1499 - val_loss: 13.1958
# Epoch 4/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.1723 - loss: 13.1256 - val_accuracy: 0.1499 - val_loss: 13.1958
# Epoch 5/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.1704 - loss: 13.0728 - val_accuracy: 0.1499 - val_loss: 13.1958
# Epoch 6/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.1660 - loss: 13.0630 - val_accuracy: 0.1499 - val_loss: 13.1958
# Epoch 7/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.1561 - loss: 13.1633 - val_accuracy: 0.1499 - val_loss: 13.1958
# Epoch 8/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - accuracy: 0.1840 - loss: 13.1848 - val_accuracy: 0.1499 - val_loss: 13.1958
# Epoch 9/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.1771 - loss: 12.9899 - val_accuracy: 0.1499 - val_loss: 13.1958
# Epoch 10/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.1698 - loss: 13.2415 - val_accuracy: 0.1499 - val_loss: 13.1958
# Epoch 11/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.1775 - loss: 13.1678 - val_accuracy: 0.1499 - val_loss: 13.1958
# Epoch 12/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.1715 - loss: 13.0324 - val_accuracy: 0.1499 - val_loss: 13.1958
# Epoch 13/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.1498 - loss: 13.2239 - val_accuracy: 0.1499 - val_loss: 13.1958
# Epoch 14/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.1706 - loss: 13.0616 - val_accuracy: 0.1499 - val_loss: 13.1958
# Epoch 15/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.1616 - loss: 12.9560 - val_accuracy: 0.1499 - val_loss: 13.1958
# Epoch 16/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.1721 - loss: 13.1442 - val_accuracy: 0.1499 - val_loss: 13.1958
# Epoch 17/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.1824 - loss: 13.0824 - val_accuracy: 0.1499 - val_loss: 13.1958
# Epoch 18/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.1787 - loss: 13.2863 - val_accuracy: 0.1499 - val_loss: 13.1958
# Epoch 19/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.1684 - loss: 12.9826 - val_accuracy: 0.1499 - val_loss: 13.1958
# Epoch 20/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.1723 - loss: 13.2751 - val_accuracy: 0.1499 - val_loss: 13.1958

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %%
###TensorFlow's tf.data API to load and preprocess the training and validation datasets
#for a machine learning model.
# TensorFlow to automatically tune the buffer size used for prefetching data during training
# This transformation caches the dataset in memory after the first epoch, 
#which can speed up subsequent training iterations by avoiding the overhead of loading the data 
#from disk or generating it on the fly.
###  The argument 1000 specifies the size of the shuffle buffer. In this case, the buffer will hold up to 1000 
#samples at a time

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
### create a keras.Sequential model that applies a series of data augmentation transformations to 
#the input images.

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height, img_width, 3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomTranslation(1, 0.5, fill_mode="reflect", interpolation="bilinear", seed=None, fill_value=0.0),
    layers.RandomCrop(img_height, img_width),
  ]
)
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:18: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Crerate the model
num_classes=9
model = Sequential([
  data_augmentation,
  #layers.experimental.preprocessing.Rescaling(1./255),
  layers.Rescaling(1./255, input_shape=(180, 180, 3)),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(256, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
## compile the model with without Dropout and softmax layer
model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 1
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 130s 2s/step - accuracy: 0.1579 - loss: 7.9947 - val_accuracy: 0.1790 - val_loss: 7.7213

# %%
##Accuracy is very very low hence skiped the execution.

# %%
import matplotlib.pyplot as plt
epochs=1
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)



plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Get the all path list for the images
from glob import glob
path_list = [x for x in glob(os.path.join(data_dir_train, '*', '*.jpg'))]
lesion_list = [os.path.basename(os.path.dirname(y)) for y in glob(os.path.join(data_dir_train, '*', '*.jpg'))]

len(path_list)
# Out:
# 2239

# %%
# Get the original DF from the train folder
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     C:\Users\hp\Downloads\Python\NN\SkinCancer_ISI...  actinic keratosis
# 1     C:\Users\hp\Downloads\Python\NN\SkinCancer_ISI...  actinic keratosis
# 2     C:\Users\hp\Downloads\Python\NN\SkinCancer_ISI...  actinic keratosis
# 3     C:\Users\hp\Downloads\Python\NN\SkinCancer_ISI...  actinic keratosis
# 4     C:\Users\hp\Downloads\Python\NN\SkinCancer_ISI...  actinic keratosis
# ...                                                 ...                ...
# 2234  C:\Users\hp\Downloads\Python\NN\SkinCancer_ISI...    vascular lesion
# 2235  C:\Users\hp\Downloads\Python\NN\SkinCancer_ISI...    vascular lesion
# 2236  C:\Users\hp\Downloads\Python\NN\SkinCancer_ISI...    vascular lesion
# 2237  C:\Users\hp\Downloads\Python\NN\SkinCancer_ISI...    vascular lesion
# 2238  C:\Users\hp\Downloads\Python\NN\SkinCancer_ISI...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
### Get Class distribution

# %%
from sklearn.preprocessing import LabelEncoder
from collections import Counter
# split into input and output elements
X, y = original_df['Path'], original_df['Label']
# label encode the target variable
y = LabelEncoder().fit_transform(y)
# summarize distribution
counter = Counter(y)
for k,v in counter.items():
	per = v / len(y) * 100
	print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
# plot the distribution
plt.bar(counter.keys(), counter.values())
plt.show()
# Out:
# Class=0, n=114 (5.092%)
# Class=1, n=376 (16.793%)
# Class=2, n=95 (4.243%)
# Class=3, n=438 (19.562%)
# Class=4, n=357 (15.945%)
# Class=5, n=462 (20.634%)
# Class=6, n=77 (3.439%)
# Class=7, n=181 (8.084%)
# Class=8, n=139 (6.208%)

# %%
# created 300 sample for class actinic.

datapath = pathlib.Path("C:\\Users\\hp\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\")
import Augmentor
p = Augmentor.Pipeline(datapath)
#Every function requires you to specify a probability, which is used to decide if an operation is applied to an image as it is passed through the augmentation pipeline.
p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
p.zoom(probability=0.5, min_factor=1.1, max_factor=1.5)
p.zoom(probability=0.2, min_factor=1.1, max_factor=1.2)
p.sample(300)
p.process()
# Out:
# Initialised with 114 image(s) found.
# Output directory set to C:\Users\hp\Downloads\Python\NN\SkinCancer_ISIC_Dataset\Train\actinic keratosis\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x22BC1361D10>: 100%|██████████| 300/300 [00:02<00:00, 105.83 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x22BC0D20450>: 100%|██████████| 114/114 [00:01<00:00, 103.35 Samples/s]

# %%
# GET image count
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 414

# %%
### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
#path_list_new , lesion_list_new
# Out:
# (['C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_0af39938-73ba-49ae-a857-d5f1e4bc2bbe.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_17287415-c886-4bfb-8ac4-000e06fa45df.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_2f133f41-bc91-4e97-92f5-7d5902035ff3.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_8042f6c7-c830-4c9a-8fbc-c77bcf712cb2.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_b7a1feb8-703b-4daa-b37b-aeef8d309be1.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025803.jpg_8b8da489-de52-4ea0-9447-02007a02c786.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025803.jpg_bfd8c00f-ed33-47c3-8a35-910acabd1407.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_418bc38a-406c-49a8-ae5d-f0a45c605b2c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_8b8e7010-a56f-406d-b3e8-26828e85ae0c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_d6307b5d-6f00-4542-9fce-8b418ac2cccf.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_e66dbfef-ce79-4c2b-8eb7-4c266650c16d.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025953.jpg_677a3bbf-a551-49f1-9e9a-2301f7155d5d.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025953.jpg_8bae3e65-3e25-499f-a5bb-1173e4c92460.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025953.jpg_deb49fd1-07c2-4444-9503-8b8450dc5bbd.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025957.jpg_6d937dd5-851e-4fe0-aa13-3c9022adb639.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025957.jpg_f0bcfd88-eda9-45c0-95d2-d7e2bb791d03.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025957.jpg_f25f4e4a-a94a-4808-9614-813f361019e5.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025992.jpg_ad21b236-67d9-455a-9219-3369c52e0dcb.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025992.jpg_e5a8d9f8-b07f-47d1-8dc1-5f35d0162de9.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026040.jpg_9d34202b-2d5a-4a0e-9f81-2dd42e0901f3.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026040.jpg_a85b72ec-8e6f-4f9e-9870-e686ee5a2611.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026040.jpg_ae91df60-2a7c-400f-8cb1-98d799e026b2.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026040.jpg_fea87585-5816-4437-acef-c76f185f5131.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026149.jpg_0c0a29ee-4243-4e5c-813d-b2f054c7ee24.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026149.jpg_4075398f-dddd-416e-8e6b-e4c1c201a8b7.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026149.jpg_50ecb9df-4100-4aac-b5f9-716337c3468a.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026149.jpg_6b420d37-c151-4d07-98c9-9ed0b1acaa16.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026171.jpg_806bbbb5-3a5e-4d8f-9913-8ab51693553b.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026171.jpg_ba9f0c0c-8af9-4b8c-972a-2c5412f3996d.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026171.jpg_c8403857-bc74-44a8-9df5-d4b886bb0b2e.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026194.jpg_27d9a001-a0c9-43de-a455-76bba3fcc5c6.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026194.jpg_7ec83529-3629-49c4-b7b9-0b2808a9093c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026212.jpg_320c6813-eee3-40b4-822c-ef725cb247c8.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026212.jpg_63b96818-986e-4cff-a5c1-13fd693ecb4f.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026212.jpg_bb909035-1eaa-49a0-8b5a-b2da9fe4e777.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026212.jpg_c00d8f15-ba37-4b9b-880d-ceb7648d4cdd.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026457.jpg_b633e545-9184-4390-ad81-bb3b90f02581.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026457.jpg_be5ad88f-5267-4bba-8db5-5dc8b2209dfb.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026457.jpg_fc6fd706-eb8f-4138-a3a0-68ea67cc3a0d.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026468.jpg_21216745-cbb4-40d6-a48e-601904961e7b.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026468.jpg_284b486b-70f6-4c47-a80f-b1e324e4e772.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026468.jpg_97bd55b0-60db-4386-88c8-3c5d24b35d97.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026468.jpg_d8b97699-d954-41b6-a2a4-3bfa432606ba.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026468.jpg_e85353b7-56e3-4bc7-b1a4-6a5ef5e4dec7.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_097e57a9-9712-4886-a4ad-103b3edd2013.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_3af8ebbd-3243-42b3-85a0-957d9f56cdb6.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_418b3185-8eb0-4198-bc95-92bccbf3703d.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_6e1af5cd-7764-4ab5-b8d7-aaf48f0b03ea.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_8ffae911-a168-4a51-9673-4e5e042587aa.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_a85b36b5-1abb-48a0-8088-86cd5aebdef1.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_adc54f87-2a4e-4289-bd18-caec4d98fcf8.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_afb5a491-e8ad-445d-89e9-670763e227d2.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_c28eb7ed-7e01-4eab-b594-736369bf68e8.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026575.jpg_07626b5c-93b4-49b4-b4bb-e668731e7b82.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026575.jpg_2e311e18-d926-4a80-864d-7f6453b333bd.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_383ca8cf-164a-4667-9ff5-906b9ee65dfd.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_3e7e9f99-1030-4990-855d-b4901919c0db.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_67d9091b-3ddd-4f3e-b401-77245e399beb.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_97f5bc90-1d12-4474-8b01-221046c8c87c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_c085adff-6a03-4da4-b68a-8dc0b266b716.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026626.jpg_85fac25f-64ba-43b6-a173-2222a2ce1fb9.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026650.jpg_598abdf4-cccb-45bf-bd52-9a05261f5da5.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026650.jpg_c106fb6e-ab5c-47e6-bb56-afb4eb86d9be.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026650.jpg_ea005de8-1cf8-4bd8-b8fd-3d4dcf2ca86e.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026702.jpg_934a37a7-ef79-4040-9d8a-a6b0b724b2a1.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026709.jpg_36f313cc-067e-4222-9783-4e067ee40a71.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026709.jpg_530e97e5-097c-4511-a9c3-3b3b7ac80841.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026709.jpg_709a7116-6d05-4d06-bb56-a85aa9ceb476.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026729.jpg_1bd15472-afe2-438c-88c0-721ff29ca9e3.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026729.jpg_33718843-25d9-462b-997f-c305e5c453f8.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026729.jpg_3539221d-7456-41bc-b7a6-bf6305270c90.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026729.jpg_499ab396-0ea1-4dfa-8bdb-d5f88dc9f957.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026729.jpg_7663d5d6-ff8b-4785-9e86-8c2daa8ac48c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026729.jpg_bdf91c29-f946-4486-92c1-0a708decc53b.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026729.jpg_eecec09a-2fc8-490f-b6ef-798acb206157.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026765.jpg_315f2486-4fc3-4ed9-b78b-1aa1b6077274.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026765.jpg_416647dc-61e7-477e-8d17-6d18adcf7114.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026765.jpg_64581c7d-80f0-4420-897d-41e967fbc80a.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026765.jpg_dfe39f76-8150-4f25-89f6-fbc91c723d3c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026848.jpg_2cb7c976-25c4-449d-aa04-03442e1b0f4e.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026848.jpg_396972e7-144f-4c3b-817e-25c533462aee.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026848.jpg_63fde306-72af-4936-8aaf-8ebf0e07a1e5.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026848.jpg_77b69fd5-b6d9-4feb-9f2a-0c456cfec090.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026848.jpg_b92cbc82-19d6-4093-98ba-2841c7cfd26a.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026857.jpg_373df2ab-7261-4c31-85f4-28ca63c957dc.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026857.jpg_4c7a876f-2d03-4a5a-af89-624890b09f7b.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026857.jpg_5f2b2ab7-ec23-40ab-a65e-addf40decee6.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026857.jpg_7c0a3744-a5b0-4bb6-927e-7d9154881b1f.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026857.jpg_d9d24f2f-43aa-4d11-9cee-b556cd9c8acb.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026905.jpg_29d9b8ce-2ca8-41ad-a2e6-10e981961097.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026905.jpg_3bce1707-c530-4564-b594-3f011435f9b2.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026905.jpg_5dec6844-cc15-4d5f-ac84-f42b0c9402e7.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026905.jpg_f5050d9b-b23c-455a-87c7-46d571a71969.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026984.jpg_1be98a0b-0a7c-4ecb-b5c9-58b3699fda1d.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026984.jpg_554beda5-c154-435c-bff8-d9e024eff80c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026984.jpg_c4221ef0-2613-426b-87f5-d9522cf491aa.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026984.jpg_e0186af5-fca9-474b-abdb-44202a2c926e.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027172.jpg_2085c6ef-0b63-4f27-91cc-b9241761f190.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027172.jpg_8b8133bc-bff1-4cb4-a8fe-c157aef28eff.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027172.jpg_b7d832d7-2a2b-4b82-942c-1af92ab2692f.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027254.jpg_1ae7f3e1-3f80-403c-96fe-e089bfa0bae5.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027254.jpg_a83f385d-bb0b-43a4-9631-f24450b8b13d.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027254.jpg_b8f9469b-d31f-4c15-bcbc-2040fae65c92.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027254.jpg_d49c29f2-9f78-4308-8b98-6169610343ce.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027254.jpg_d6c90fda-33b6-474d-8aa8-0576fd7986e4.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027334.jpg_06bb782b-78fb-4b41-bb37-7253384b214c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027334.jpg_41743548-d195-44dd-9bfe-4463857df2d1.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027334.jpg_6b5e7a68-07b8-4e18-b68e-994ee808fde2.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027334.jpg_879a3f57-4b61-4b49-bfb6-9af9f92b2a09.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027334.jpg_93cf7ba9-328e-4c15-9705-4fc07e2ff25e.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027447.jpg_5f79bee2-ada2-4510-bfbb-919a565765c1.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027447.jpg_72a565b7-0d1c-4e5a-82a5-b6207a9ab07a.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027447.jpg_77cf2d9d-7d12-445e-ba38-ac71323909fc.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027447.jpg_e363ac24-a304-4fcb-81da-ab14a9ce952d.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027452.jpg_2adba10f-5499-49cf-9f5f-591e3f326b79.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027452.jpg_59cd83db-674f-4f8a-b199-48a0b04ef9d4.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027452.jpg_702d72f8-399d-4a7d-b4dc-ce5df85e62e5.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027452.jpg_a44b562a-8aac-41db-b823-ba66c713180d.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027452.jpg_d2f0a9f7-4140-4740-ab0f-fc01881191e5.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027536.jpg_402c5b3c-a7d5-4e14-936f-f7e8d3c3de64.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027536.jpg_675b4440-deec-4fb0-84c5-4f5cbf9a3c48.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027536.jpg_6a4785a3-4410-410f-9045-5ad0d21b0a8c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027536.jpg_b119b247-659e-4e86-b443-90c0c9a568b1.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027562.jpg_6abb0d2b-36b2-4702-9e01-1cd460886c65.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027562.jpg_c63ee66b-7419-4bfa-831f-d8e66ff29265.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027580.jpg_47dfc546-7457-404c-b0a1-5fe436c1e9f9.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027580.jpg_5eca718a-80d8-4060-9b59-302d062b3a71.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027580.jpg_6d450d74-a65a-48c3-9626-4ae6739d59ed.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027615.jpg_4928d55a-eea9-4ce0-9f6f-86274a0194ff.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027615.jpg_85e9b8c8-7a9f-4d3b-8734-db9b04944986.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027615.jpg_871b06f3-640c-469e-befc-89503a3becdf.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027615.jpg_ac340716-09a9-4068-84cb-985757bbf225.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027615.jpg_fef08c36-c24e-4b0a-9f98-16fb7d0abdf3.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027650.jpg_0f9009ae-7698-41a8-a82b-4952f850172b.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027650.jpg_108fbdcc-da4d-4a22-8c26-3da359eef8e1.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027650.jpg_52049ef4-6d6a-41b0-bf86-e2cc20d36e29.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027650.jpg_58225afd-f739-4ff3-a754-e882141d493a.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027650.jpg_bba1e47b-829b-4873-9e59-33032e032eec.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027650.jpg_bcaa857d-fa36-4a69-9af7-db80d9b8238c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027650.jpg_c0834361-b3c8-45a0-b5e4-055601bddc05.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027650.jpg_f250916d-d264-496b-b4da-da8a80a375e9.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027668.jpg_3c849166-00fd-41e5-9628-54f354bb31eb.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027668.jpg_4a67df82-24d3-4be8-a367-1f4e29d1cb6c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027668.jpg_c62d5d82-873c-419f-b456-67e78faf1ced.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027668.jpg_e4298697-f0da-42e2-ac49-eb0a1998834c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027802.jpg_2fa6ef17-cd62-41c4-b8d1-483b8c128325.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027802.jpg_73aa7bc3-5124-45b7-94e1-f17d0e6ff9cc.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027829.jpg_0e3918c8-7859-423a-850e-486db95f2d2f.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027829.jpg_16db5f5c-d89c-44e2-937d-432522fabef1.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027829.jpg_99dc7d35-03a4-4170-8b48-e3ffda1c4899.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027829.jpg_a9e02fb5-f347-4440-8ca8-5bbb74714812.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027829.jpg_d5ba64a8-98d1-47e7-8ae1-7e560ea7e80e.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027884.jpg_ae4273fd-47a7-4c02-ad9f-14eb0efa8286.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027884.jpg_df9289ee-0b5d-45f9-9147-4f9598166de0.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027896.jpg_18818b5b-ca1e-456e-9da0-ab1a71e3b013.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027896.jpg_26c95aba-7cf5-4df1-ba7d-2db27e09c033.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027896.jpg_3abcacd5-1ee9-445d-8a1d-a4bcfe505922.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027896.jpg_a6d272ff-222c-4608-bc2e-b82a8e606d34.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027896.jpg_e4bb7695-8bb0-4f03-943d-06cff03afd3a.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027896.jpg_e77b107d-cb2b-4f64-86ff-e6d2a654f7f2.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027950.jpg_02b64ec6-330b-4dfe-ae34-6c9f4757467d.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027950.jpg_7655b2ad-f093-4c3f-a277-9742384efb90.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027958.jpg_1643cefe-013e-4f2f-9608-1dabe3787f79.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027958.jpg_28fec0c1-c454-48aa-8ea3-160221b010cf.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027958.jpg_4ca1bb1e-e365-4a24-a095-4d71ca78cf61.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027958.jpg_b65cd60d-533d-4b37-97c9-419d10820614.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028063.jpg_8efc0e52-e4ef-45a0-8cc9-6025fb240ef1.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028063.jpg_9d19efc4-ac0a-45f0-a69c-04b370387582.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028063.jpg_a6f4cbe1-489d-4515-ac25-28bf457666fc.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028063.jpg_b1653aef-f7c7-4bc4-a473-e59a5e04fe94.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028063.jpg_c9f7a2ff-6f00-44d2-ac23-08921f27ba0a.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028063.jpg_ea78bbb3-0239-4b81-a1af-1ec2e4f2079c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028063.jpg_f30b5373-6345-43d5-bb29-52d8580d7465.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028076.jpg_028391b9-0a4f-4b07-b39b-196a95550b9a.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028076.jpg_0c1689ef-a6ac-4676-8155-46d2110a5c6b.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028076.jpg_641b621d-0104-4b66-ad01-52190332ad72.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028076.jpg_8c211ce4-1446-47d7-9a8a-ee1e5ec7a6cc.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028076.jpg_ac2d2d3d-8231-4d65-941b-877cdd994498.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028076.jpg_b7f04f70-98f7-4e70-8a1e-8cdce2c007ee.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028076.jpg_fd5322ec-d3c3-4f9d-8133-e2d13049be0d.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028190.jpg_26aec9a0-c051-4971-83f6-410d95271efc.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028190.jpg_7c0956c6-a040-4ccc-a7af-12949e1f31df.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028190.jpg_9a33d1ad-b641-4957-9f69-30a0d2ab3a36.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028190.jpg_ef423b27-430e-49ce-b189-ee5911b6d861.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028314.jpg_2f220184-e95d-41a9-94ae-ba87cce7b20d.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028314.jpg_33f76b08-05a7-4efd-a3d2-6c5d3646db49.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028314.jpg_58880258-951c-45c6-94c1-690f48b9d0bc.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028370.jpg_6ced6271-ef03-4e6b-9ee2-98fc6d0f2b48.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028370.jpg_aa3d5f5f-6a68-4feb-977e-3bf197371236.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028370.jpg_f9101780-0459-405a-ae24-a81f518fed28.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028393.jpg_35fcb90d-358d-43f2-8f87-9b554ff08638.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028393.jpg_43d08acd-54e1-4fc0-845f-07c257a2a2f7.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028393.jpg_58d653dd-1551-4b99-bfc3-267f92370dfa.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028393.jpg_7cdc7fd5-39a4-467e-9e43-9325c8b55510.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028393.jpg_a290e9aa-d7e7-4e49-aa61-c096f139e2be.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028517.jpg_46c3aa84-d811-47bc-8602-d83aeab4b9d1.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028517.jpg_708ca7ce-9310-4897-a4ab-4e7dead21b9b.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028558.jpg_933737f5-0c85-4519-8072-e9801a380c84.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028558.jpg_a60cd904-4198-46fb-ae87-c7dadb93ebd4.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028820.jpg_00f80488-aa03-47b7-87cd-c2584113c076.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028820.jpg_5fd3db78-c1e9-4a24-8a91-929743464495.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028820.jpg_8d949a33-e84a-4a27-8f08-8162a65b182d.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028820.jpg_9d1649dc-a61c-4fe4-8867-f0815d055d6c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028854.jpg_59743110-d916-4e6e-a816-f58209363701.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028854.jpg_74c54bf7-1f28-4b1d-ae3b-616306d93934.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028854.jpg_f6353df9-fba4-4e64-b830-dd8931c0c92b.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028941.jpg_22732bab-7d91-40ec-8599-883e60aa1b05.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028941.jpg_537ace3f-99e8-48d4-bc8c-a97a015d437a.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028941.jpg_c19a93a3-04f1-484e-b6ca-d74e3c69d5a7.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028990.jpg_8b9ba7b3-e897-4aae-be35-665df49e307c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028990.jpg_bf7ceb5f-78a5-4d96-99e9-eb5910d80ebe.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0028990.jpg_ec23a233-5398-4c16-92e5-c4bbc830a74d.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029025.jpg_5f38cbac-1041-44e2-96b8-61362a4b8805.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029025.jpg_7c151b8e-8fe0-4bf6-aca6-53d63469eac9.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029025.jpg_9c6b7833-9ace-4b32-a2c8-16eabc1d44a8.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029041.jpg_4cf4e849-1a41-4745-8690-5d03cbf790fb.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029041.jpg_6748030a-d411-427c-8b4c-348b86bae0f6.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029041.jpg_75d6d315-eb25-4c74-b1af-a4baafff8936.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029041.jpg_991cc625-6a8e-4979-887e-ac88e8f6b159.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029041.jpg_fb6911e1-6f7b-4e1f-835f-eb2681da1618.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029133.jpg_49710290-ae07-439c-b511-ddeafad7a9e1.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029133.jpg_789dd4e3-a90f-4a37-9898-cb47740c7ce0.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029141.jpg_5aa97562-b96c-4844-b997-bf2231559b8e.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029141.jpg_95bff4ad-bc81-4859-8223-b0edf0e8b3d2.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029141.jpg_e10a595d-60af-4f1a-a65d-8ffde044a257.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029141.jpg_f8cce3ab-f7d0-45e9-80f2-cd80bd9184ee.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029210.jpg_3ae342df-c155-44f5-81e5-b541b8706151.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029210.jpg_3b858ecc-dff1-4c4e-ae79-88fbe3a93915.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029210.jpg_61a04aa8-773a-4be1-8f00-c3af6b99d044.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029210.jpg_fd504db0-54fe-4017-9eca-b71025be9342.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029309.jpg_c462e58b-4627-4692-8bdb-a67916deafe8.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029460.jpg_2a92beb9-ea34-416f-857e-0264d2ee0373.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029460.jpg_423a65ae-c9b2-4263-98e8-561b5d6bb050.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029460.jpg_6642443c-07f0-49c0-a8ff-df0083159878.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029460.jpg_f275b152-80de-4853-b745-5280dca5829e.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029500.jpg_7ada07a0-bffe-405d-a32e-4ed64eb5f00f.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029500.jpg_9d136e52-8c40-44cc-9f6a-4ae90bdcc966.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029500.jpg_ac9623a8-f625-4c1c-97fd-8a52beb1f26b.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029500.jpg_cfde0e9c-ddc6-4de4-b1cf-1644015aecb0.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029500.jpg_e749318e-902a-48d7-bfae-35249db5165c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029659.jpg_1ee8a176-218e-4052-b4b9-62da2d062ff0.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029659.jpg_3b4c5996-e505-444d-983f-1ec7f9d285e6.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029659.jpg_3daf34f9-5c5c-4698-8dff-1108145d72e0.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029659.jpg_4e90958f-6fee-4c6c-bfa5-6d11539a8b7b.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029659.jpg_90bffd6d-c33a-423a-876a-c7f596735d3c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029659.jpg_9d75795a-8074-4d14-bf5d-58db730fe96e.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029659.jpg_a0a5d66f-da5a-425c-8267-99fce0e2f48a.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029659.jpg_b746a600-0479-4626-a8ca-0fff99b92bc9.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029659.jpg_c9cecb13-0149-45f1-a95e-bf7ac963fe82.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029713.jpg_092fe565-551b-459c-b332-31ce92102afb.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029713.jpg_50370527-7a09-4765-8134-df84d6e8932e.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029713.jpg_6aa99639-8af0-46c2-ad0d-9479962ad17b.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029713.jpg_b8722bd9-cbf4-4f95-813b-ab7340da50f5.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029713.jpg_dd340021-e6e6-4b73-92c2-14f043fc7018.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029781.jpg_05e908ca-ee11-4e81-8495-cb96a9bf42f6.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0029781.jpg_3587ccf6-c2ad-439c-915d-882b6ffb18f6.jpg',
# ...
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0032437.jpg_f438c704-a1d5-4a0e-a90c-8dae8e666ccc.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0032854.jpg_0b7ade60-8470-4973-8c7e-08cfd68db564.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0032854.jpg_426f49b1-f875-4deb-b408-68ca2879dbce.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0032854.jpg_a44114bf-ac57-4fe1-991d-f1be3143feb4.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0032854.jpg_e2ee80f2-2476-4bc3-820d-0de5b38f568b.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033151.jpg_573b36f6-a06d-46b4-aa33-9b9ade00c815.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033151.jpg_77b88bd0-b49c-4838-90f8-e02654c425b2.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033151.jpg_9e6c93f1-30dd-4417-915a-7e9481ae9c5e.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033358.jpg_8c66ab7b-c62f-4fab-820d-be73b779ce09.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033358.jpg_95395b46-eb11-4ea8-913e-0fa65a8bcc04.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033413.jpg_1677b7fe-a5d6-4067-90fa-431b751c6286.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033413.jpg_2cf47dc9-edb9-47ed-85d1-1ce59116c637.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033413.jpg_3b79f85d-1c90-40e9-9d91-2688d5612687.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033413.jpg_5ce1d782-0106-4ece-923f-1106e7b17505.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033413.jpg_667e4f4e-22d7-4ab4-9572-74dc2dcd42d1.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033456.jpg_3642acb6-11d6-4ee6-bdaa-bed0cdd71b27.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033456.jpg_9510155d-511d-4243-8944-c7fd7e486dd1.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033456.jpg_9fc7b192-a60c-42ca-9570-d28d6465fa8c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033456.jpg_ce4c27f7-38e4-4ec1-bdf1-9cf12e785942.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033456.jpg_fe9bf055-ab85-409c-a5bd-0e677da59c3d.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033494.jpg_1783f127-04d1-4167-9ebc-0783995d8ec5.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033494.jpg_502e98c9-81c8-425c-a7de-e6b15ef5de03.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033494.jpg_619e02e0-1bda-427d-ba37-bd7ba5fa674e.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033705.jpg_3b1f3bc5-0b1d-4dc5-a918-d7c1ab93ee9e.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033705.jpg_57766b23-683e-4892-b55d-555c06b6b8d3.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033705.jpg_7a403a81-dcad-48aa-8ce7-126fb7fd2d8a.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033705.jpg_d3e38ccb-e4c8-4d0e-9606-d72df8d01bae.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033705.jpg_d5491b78-51d3-4629-831f-910bc7dad06c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033811.jpg_12a46bb4-3308-454c-bb31-ff480cad474f.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033811.jpg_82d6e455-2604-49ab-8369-2b80df5e8fd5.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033811.jpg_ed8a9955-344c-4b42-b056-345c8846b731.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033866.jpg_467d14fb-1edc-4c94-a7a2-1077cd31536c.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033866.jpg_d5767f94-2a17-4a92-984f-b5d0a3788b61.jpg',
#   'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0033866.jpg_dddad569-9718-4574-95a7-205b5fc0f264.jpg'],
#  ['actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis',
#   'actinic keratosis'])

# %%
# Create images using Augmentor, 500 sample for each class
path_to_training_dataset="C:\\Users\\hp\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500)
# Out:
# Initialised with 114 image(s) found.
# Output directory set to C:\Users\hp\Downloads\Python\NN\SkinCancer_ISIC_Dataset\Train\actinic keratosis\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x22BC1489310>: 100%|██████████| 500/500 [00:03<00:00, 128.32 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to C:\Users\hp\Downloads\Python\NN\SkinCancer_ISIC_Dataset\Train\basal cell carcinoma\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x22BC13731D0>: 100%|██████████| 500/500 [00:04<00:00, 120.93 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to C:\Users\hp\Downloads\Python\NN\SkinCancer_ISIC_Dataset\Train\dermatofibroma\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x22BC0D1C250>: 100%|██████████| 500/500 [00:04<00:00, 124.26 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to C:\Users\hp\Downloads\Python\NN\SkinCancer_ISIC_Dataset\Train\melanoma\output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x22BC1022250>: 100%|██████████| 500/500 [00:23<00:00, 21.25 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to C:\Users\hp\Downloads\Python\NN\SkinCancer_ISIC_Dataset\Train\nevus\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=919x802 at 0x22BC0455310>: 100%|██████████| 500/500 [00:21<00:00, 23.53 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to C:\Users\hp\Downloads\Python\NN\SkinCancer_ISIC_Dataset\Train\pigmented benign keratosis\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x22BC0C4A590>: 100%|██████████| 500/500 [00:04<00:00, 110.27 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to C:\Users\hp\Downloads\Python\NN\SkinCancer_ISIC_Dataset\Train\seborrheic keratosis\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x22BC1456C90>: 100%|██████████| 500/500 [00:10<00:00, 47.07 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to C:\Users\hp\Downloads\Python\NN\SkinCancer_ISIC_Dataset\Train\squamous cell carcinoma\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x22BC134BC50>: 100%|██████████| 500/500 [00:04<00:00, 121.98 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to C:\Users\hp\Downloads\Python\NN\SkinCancer_ISIC_Dataset\Train\vascular lesion\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x22BBE918250>: 100%|██████████| 500/500 [00:04<00:00, 119.08 Samples/s]

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4914

# %%
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list_new
# Out:
# ['C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_0af39938-73ba-49ae-a857-d5f1e4bc2bbe.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_0b35afda-58bd-4cb1-97bd-53be5818803e.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_17287415-c886-4bfb-8ac4-000e06fa45df.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_2f133f41-bc91-4e97-92f5-7d5902035ff3.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_4cf86264-45c3-4ff9-8d1e-1f3551a03b01.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_583c8c67-9065-4b07-9c76-674155f59af2.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_8042f6c7-c830-4c9a-8fbc-c77bcf712cb2.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_9da23c5f-a14b-4ed7-831e-7ad4bcd61627.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_b0d449fb-c863-4edd-8256-4ae3f1a04cfb.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_b7a1feb8-703b-4daa-b37b-aeef8d309be1.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_d481ad52-cddc-4a8a-94f6-577587cf9ded.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_fe927403-8e3b-46b2-be84-fec357a2ed7f.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025803.jpg_060be8d3-53a5-48c5-a285-c9e6779d6d5a.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025803.jpg_419739f6-6a8c-4fc4-a8b2-42ed75cc770a.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025803.jpg_616c0065-323d-45ca-a35a-ae75a9923143.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025803.jpg_8b8da489-de52-4ea0-9447-02007a02c786.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025803.jpg_9b19c909-0171-44c1-b14c-9a8699cc4583.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025803.jpg_bfd8c00f-ed33-47c3-8a35-910acabd1407.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025803.jpg_cf487952-b887-444c-bf0a-57cb96b0d0e8.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_0f745d84-b3a5-44e2-908e-1705cad87f11.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_33b5c40b-34d5-4539-afc7-b53ffe3ef8bb.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_418bc38a-406c-49a8-ae5d-f0a45c605b2c.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_753619c3-a291-498d-a006-f03310983c92.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_8b8e7010-a56f-406d-b3e8-26828e85ae0c.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_c866c11b-0cb3-4b52-8491-b652556fc947.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_d6307b5d-6f00-4542-9fce-8b418ac2cccf.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_e66dbfef-ce79-4c2b-8eb7-4c266650c16d.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025953.jpg_1bb25ac0-e074-44b7-8048-a53efa3f23b5.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025953.jpg_677a3bbf-a551-49f1-9e9a-2301f7155d5d.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025953.jpg_733f515c-9c55-4533-b2fa-8ee0182524cc.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025953.jpg_8bae3e65-3e25-499f-a5bb-1173e4c92460.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025953.jpg_a15a1fde-376f-4f73-bb95-ff4f38ab9c48.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025953.jpg_deb49fd1-07c2-4444-9503-8b8450dc5bbd.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025957.jpg_49ffddb4-0b36-45be-94f8-8e404b980e75.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025957.jpg_670a0467-a399-413f-a86e-9c1b685e231a.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025957.jpg_6d937dd5-851e-4fe0-aa13-3c9022adb639.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025957.jpg_b9817d6e-a129-43c1-8832-9d21c504ef43.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025957.jpg_dc7396ce-24bf-4022-9679-af54bb89f724.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025957.jpg_f0bcfd88-eda9-45c0-95d2-d7e2bb791d03.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025957.jpg_f25f4e4a-a94a-4808-9614-813f361019e5.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025992.jpg_25cdca8e-59af-46f4-8f67-e0a5fa7fb399.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025992.jpg_2d45475e-eb0d-4170-8299-7ce41f03fd1d.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025992.jpg_ad21b236-67d9-455a-9219-3369c52e0dcb.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025992.jpg_d10d60f7-091a-48ae-94a1-7da18e6895ce.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025992.jpg_e5a8d9f8-b07f-47d1-8dc1-5f35d0162de9.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025992.jpg_fbd6dc62-8c37-4048-9393-2bbe5a3bfe6c.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026040.jpg_15c68145-727e-40e7-a571-f7da40e6924d.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026040.jpg_7a6ab8a8-3718-468f-a5f5-129a82592ccb.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026040.jpg_9d34202b-2d5a-4a0e-9f81-2dd42e0901f3.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026040.jpg_a68effbb-a868-4f88-b76b-6349c09cb595.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026040.jpg_a85b72ec-8e6f-4f9e-9870-e686ee5a2611.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026040.jpg_ae91df60-2a7c-400f-8cb1-98d799e026b2.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026040.jpg_e59d75b0-26c8-472a-a5c4-0e3e73d7715a.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026040.jpg_fea87585-5816-4437-acef-c76f185f5131.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026149.jpg_0c0a29ee-4243-4e5c-813d-b2f054c7ee24.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026149.jpg_1339001a-425f-45f6-844e-fbff63c09060.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026149.jpg_145c76fd-69cc-48dd-b317-2e36f4a0c6c1.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026149.jpg_4075398f-dddd-416e-8e6b-e4c1c201a8b7.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026149.jpg_50ecb9df-4100-4aac-b5f9-716337c3468a.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026149.jpg_5ad40f05-f26c-4cf3-91e4-21b033756922.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026149.jpg_63705de6-d46e-404a-92eb-755522587ade.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026149.jpg_6b420d37-c151-4d07-98c9-9ed0b1acaa16.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026149.jpg_941e5199-6622-4d35-91d8-9ba65d1119ea.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026149.jpg_b9ba53a7-217c-463c-8038-7a3496995567.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026171.jpg_806bbbb5-3a5e-4d8f-9913-8ab51693553b.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026171.jpg_ba62952d-cbd8-4fe3-b177-cb2efde960a7.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026171.jpg_ba9f0c0c-8af9-4b8c-972a-2c5412f3996d.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026171.jpg_c8403857-bc74-44a8-9df5-d4b886bb0b2e.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026194.jpg_27d9a001-a0c9-43de-a455-76bba3fcc5c6.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026194.jpg_7ec83529-3629-49c4-b7b9-0b2808a9093c.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026194.jpg_83b97ead-be60-440e-ac9e-82e8e85028a5.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026194.jpg_8b71de17-56bb-4536-9e5a-ee283be1e2d3.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026194.jpg_918ad120-f218-45f0-8a87-fcc9c985931c.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026194.jpg_d24165af-0f73-4e4f-b41a-c6eabab46641.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026212.jpg_1012fc56-5f3e-4390-87fa-42f50113ad0f.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026212.jpg_1a40d71b-01ad-4deb-b492-6d0e54884d18.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026212.jpg_320c6813-eee3-40b4-822c-ef725cb247c8.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026212.jpg_63b96818-986e-4cff-a5c1-13fd693ecb4f.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026212.jpg_84334231-9d14-4f3f-b956-8b06c1bf0b44.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026212.jpg_956ac21e-f642-4bc1-b1eb-1566985d395b.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026212.jpg_a6abb1fa-cfc6-4190-b46e-863a6925f6d3.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026212.jpg_b69effbe-4356-4eb7-9539-883c1223b413.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026212.jpg_b880f3ce-21dc-4796-9c58-d619486bc827.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026212.jpg_bb909035-1eaa-49a0-8b5a-b2da9fe4e777.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026212.jpg_c00d8f15-ba37-4b9b-880d-ceb7648d4cdd.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026457.jpg_2a4fcff5-c0f0-4a1d-9f9f-90ed56dcf20e.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026457.jpg_47d0ddb0-f411-4bf2-85b9-2b978eb8b393.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026457.jpg_5027ca5d-8ba8-4a14-90cb-15e4c13c03ca.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026457.jpg_57111954-595d-4edd-8707-1900c14e5b52.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026457.jpg_5776b50c-632c-4eea-bce1-3f8694413bb9.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026457.jpg_7682b033-6a9d-4d08-becd-50343af96cb4.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026457.jpg_8487c0cf-2570-4d05-a9cd-b134b87b2b0b.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026457.jpg_b3188c84-b4f4-4950-b973-333ecac2c0d0.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026457.jpg_b633e545-9184-4390-ad81-bb3b90f02581.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026457.jpg_be5ad88f-5267-4bba-8db5-5dc8b2209dfb.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026457.jpg_d4e3f1e6-185b-4cb6-8dd5-5179ac29dd8a.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026457.jpg_fc6fd706-eb8f-4138-a3a0-68ea67cc3a0d.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026468.jpg_0080ccfe-c77e-4f19-b75c-923b46513d44.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026468.jpg_21216745-cbb4-40d6-a48e-601904961e7b.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026468.jpg_2752afdf-f91b-4a87-af22-aeb8761a45f0.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026468.jpg_284b486b-70f6-4c47-a80f-b1e324e4e772.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026468.jpg_97bd55b0-60db-4386-88c8-3c5d24b35d97.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026468.jpg_b6227b67-bfa5-474a-ad59-9e9364d7f1f9.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026468.jpg_b92a46b1-7f6b-4dc8-b0dc-09f350b2fabd.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026468.jpg_d05bc57a-8d8c-4e36-a31e-168159bc9772.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026468.jpg_d8b97699-d954-41b6-a2a4-3bfa432606ba.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026468.jpg_e7b721f3-1824-488d-9758-f5e3b46bd285.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026468.jpg_e85353b7-56e3-4bc7-b1a4-6a5ef5e4dec7.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_097e57a9-9712-4886-a4ad-103b3edd2013.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_12b81f87-c8b6-4028-87a5-8d9a8035a86d.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_3213995b-708a-42e4-81c0-59919a3ae39c.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_3af8ebbd-3243-42b3-85a0-957d9f56cdb6.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_418b3185-8eb0-4198-bc95-92bccbf3703d.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_6e1af5cd-7764-4ab5-b8d7-aaf48f0b03ea.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_8ffae911-a168-4a51-9673-4e5e042587aa.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_95b81770-b9fa-402c-8289-c560c23cb48d.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_a85b36b5-1abb-48a0-8088-86cd5aebdef1.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_adc54f87-2a4e-4289-bd18-caec4d98fcf8.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_afb5a491-e8ad-445d-89e9-670763e227d2.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_c28eb7ed-7e01-4eab-b594-736369bf68e8.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_c57833b2-0b5c-42ca-94c5-14a7f2e89091.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026525.jpg_d0c6bb75-6a1a-4f85-816e-af00fdc2186e.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026575.jpg_07626b5c-93b4-49b4-b4bb-e668731e7b82.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026575.jpg_2e311e18-d926-4a80-864d-7f6453b333bd.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026575.jpg_7eecdbbf-8b0a-40aa-82c7-dee6f5151075.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026575.jpg_a376539e-6106-4037-ac21-538c8b37b9dd.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026575.jpg_b49700ec-1d26-44df-8b52-d2b389d0dd60.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026575.jpg_d613dbad-4c22-4de0-af50-9630c3d35d25.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_0308f54e-6b42-4ff7-8a01-17a8658729ac.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_0372994b-71a2-4886-9829-0a6f11ce55d6.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_038eefee-5960-461f-884d-972b8a8db93e.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_08a5af43-8c4c-4caa-8466-5878dcefb0e0.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_383ca8cf-164a-4667-9ff5-906b9ee65dfd.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_3e7e9f99-1030-4990-855d-b4901919c0db.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_51bf8ede-4dc7-48a3-a7a9-5b5f5683bf56.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_5724c238-90cc-4c73-bf53-41154ea57857.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_67d9091b-3ddd-4f3e-b401-77245e399beb.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_89c32a54-ce0d-4cd4-9140-99ead447d724.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_97f5bc90-1d12-4474-8b01-221046c8c87c.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_a74290c1-0133-4041-a873-7522c972f85f.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_c085adff-6a03-4da4-b68a-8dc0b266b716.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_c626642f-2cad-4e52-8b5c-78308c073758.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026625.jpg_f3230e5d-ede8-4acc-8829-59f880456ab3.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026626.jpg_0d5663f9-739e-4bb8-b81f-691df16c5c60.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026626.jpg_5706b66f-2e29-4278-aa9e-26862018c3ec.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026626.jpg_85fac25f-64ba-43b6-a173-2222a2ce1fb9.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026626.jpg_d68897d2-04e5-4b4b-8644-7b58ee5b2a94.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026626.jpg_d9a2ba18-c8c2-4a8c-9ec7-bba9fbc13a5e.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026650.jpg_1124ba28-e712-4a10-9a30-b9afcc6f397c.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026650.jpg_2809524b-c265-42f0-971e-1f30fee66d76.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026650.jpg_598abdf4-cccb-45bf-bd52-9a05261f5da5.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026650.jpg_946055b1-3fae-4efb-85fc-efcd7d1b91da.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026650.jpg_a4843af4-927f-4e47-80b5-b3370f16748c.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026650.jpg_b814dc9e-f6c7-4a5e-bf1d-4defb8486ae3.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026650.jpg_c106fb6e-ab5c-47e6-bb56-afb4eb86d9be.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026650.jpg_d7e9290b-0562-4d37-8af1-861689d57788.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026650.jpg_ea005de8-1cf8-4bd8-b8fd-3d4dcf2ca86e.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026702.jpg_0c499bdd-41e3-48b9-ae4a-148e65483898.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026702.jpg_5889d962-48fb-4ea7-9c98-b6fb277eeeb4.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026702.jpg_7140d0a7-923f-4069-992c-5cf3b4765dc5.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026702.jpg_754a52ec-d7e7-4db3-9a2d-5de38f5454fd.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026702.jpg_934a37a7-ef79-4040-9d8a-a6b0b724b2a1.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026702.jpg_a9a6d0a9-08d0-43ee-86c8-1131a282cce1.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026702.jpg_c2db89b0-eae5-42c1-a065-8d4730a6df74.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026702.jpg_cf1b648b-5c1f-4e2b-a447-9d0fcef62133.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026709.jpg_1644efb7-d5a0-4d49-a098-672a93d91875.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026709.jpg_1989f56f-d3f8-41e7-94dd-3a1b1e474847.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026709.jpg_29f7e971-026c-46db-a333-d2402f8e15a9.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026709.jpg_36f313cc-067e-4222-9783-4e067ee40a71.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026709.jpg_530e97e5-097c-4511-a9c3-3b3b7ac80841.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026709.jpg_5b9e1cd4-6fef-4a4f-863a-74743e781ec0.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026709.jpg_709a7116-6d05-4d06-bb56-a85aa9ceb476.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026709.jpg_8ec86447-22b8-42ec-9a43-542b9e594472.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026709.jpg_b37dcd0d-4869-4491-acf2-76db707b4bb0.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026709.jpg_d3c58a42-eb5d-4f5d-8d5f-a54e1c85aa45.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026709.jpg_ed9eb065-0fe3-4948-a8b9-72e6062850fe.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026729.jpg_1bd15472-afe2-438c-88c0-721ff29ca9e3.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026729.jpg_33718843-25d9-462b-997f-c305e5c453f8.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026729.jpg_3539221d-7456-41bc-b7a6-bf6305270c90.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026729.jpg_499ab396-0ea1-4dfa-8bdb-d5f88dc9f957.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026729.jpg_553b3cb1-36eb-4f49-9595-39b1cef32fc1.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026729.jpg_5f88e172-accd-4d22-8747-f09280b086d5.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026729.jpg_60e5d283-1933-4aae-87f4-fb9bd36369ac.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026729.jpg_7663d5d6-ff8b-4785-9e86-8c2daa8ac48c.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026729.jpg_a3da9021-76da-488c-90e1-e18c043ba719.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026729.jpg_bdf91c29-f946-4486-92c1-0a708decc53b.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026729.jpg_eecec09a-2fc8-490f-b6ef-798acb206157.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026765.jpg_315f2486-4fc3-4ed9-b78b-1aa1b6077274.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026765.jpg_3833e7f8-7887-48c3-9010-d08f7816aa0b.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026765.jpg_416647dc-61e7-477e-8d17-6d18adcf7114.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026765.jpg_64581c7d-80f0-4420-897d-41e967fbc80a.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026765.jpg_7cb1b552-0d46-4928-a681-9a81636e8753.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026765.jpg_dfe39f76-8150-4f25-89f6-fbc91c723d3c.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026765.jpg_f337619a-0396-4705-bddf-66a1d9b2b7c8.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026848.jpg_1585ef94-7027-485d-a7fd-5b598a8df285.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026848.jpg_16d9e6c6-aab9-417a-8377-f2eaf2dd97fc.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026848.jpg_2cb7c976-25c4-449d-aa04-03442e1b0f4e.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026848.jpg_396972e7-144f-4c3b-817e-25c533462aee.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026848.jpg_5ff0254b-3437-4dab-b355-05d4942a9a2b.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026848.jpg_63fde306-72af-4936-8aaf-8ebf0e07a1e5.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026848.jpg_68a0cdea-9fe6-4d38-b2be-52c69f2e1faf.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026848.jpg_77b69fd5-b6d9-4feb-9f2a-0c456cfec090.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026848.jpg_b92cbc82-19d6-4093-98ba-2841c7cfd26a.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026848.jpg_f5105763-fe72-49f4-8cbf-ad2d0a213987.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026857.jpg_373df2ab-7261-4c31-85f4-28ca63c957dc.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026857.jpg_4c7a876f-2d03-4a5a-af89-624890b09f7b.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026857.jpg_5f2b2ab7-ec23-40ab-a65e-addf40decee6.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026857.jpg_7c0a3744-a5b0-4bb6-927e-7d9154881b1f.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026857.jpg_85096eb0-f5c1-4c81-9a7b-4468baa181e5.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026857.jpg_af9453a5-19c1-4fe3-827f-53fd27503e9a.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026857.jpg_b415bcb5-9994-4387-adc9-b6d0ae9b9938.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026857.jpg_d9d24f2f-43aa-4d11-9cee-b556cd9c8acb.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026905.jpg_29d9b8ce-2ca8-41ad-a2e6-10e981961097.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026905.jpg_3bce1707-c530-4564-b594-3f011435f9b2.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026905.jpg_5dec6844-cc15-4d5f-ac84-f42b0c9402e7.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026905.jpg_9ff2c66d-30f4-4fec-b425-0f529bb24674.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026905.jpg_ad0060d1-603c-416b-ac8e-7a25a13d491b.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026905.jpg_b042e667-a617-4154-bfa4-c38bd945d659.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026905.jpg_f5050d9b-b23c-455a-87c7-46d571a71969.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026984.jpg_1be98a0b-0a7c-4ecb-b5c9-58b3699fda1d.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026984.jpg_3705b21b-8069-4ca2-9b0d-1aaad3ffa992.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026984.jpg_554beda5-c154-435c-bff8-d9e024eff80c.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026984.jpg_73517f71-2650-44d8-9655-327c6d42dfd3.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026984.jpg_9af0cb21-c92a-450c-bd47-a2ae71a274cf.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026984.jpg_ae46fe24-9917-4857-96bc-01eefe6cb6ac.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026984.jpg_b6de7b1d-7dd4-42b6-acfe-64d284bb6b18.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026984.jpg_c4221ef0-2613-426b-87f5-d9522cf491aa.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0026984.jpg_e0186af5-fca9-474b-abdb-44202a2c926e.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027172.jpg_0306489b-c88a-46ae-afe4-0d6589a0d405.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027172.jpg_2085c6ef-0b63-4f27-91cc-b9241761f190.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027172.jpg_26b4181d-0f6c-4244-97b2-732eb35d1b25.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027172.jpg_35d9651b-2894-4a44-9754-74f3f9feb603.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027172.jpg_74f45915-58ab-4b22-8681-1ed94d77a815.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027172.jpg_8b8133bc-bff1-4cb4-a8fe-c157aef28eff.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027172.jpg_96a83348-df89-4394-882d-3656fb3af0a9.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027172.jpg_a20ade4f-550b-409b-9e13-81275478e0b3.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027172.jpg_add94c1b-2161-4378-9ac8-4ac8c1666252.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027172.jpg_b7d832d7-2a2b-4b82-942c-1af92ab2692f.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027172.jpg_bfd455f1-7add-4a9b-a2a2-4e85f9e589d6.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027254.jpg_1ae7f3e1-3f80-403c-96fe-e089bfa0bae5.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027254.jpg_9bd654aa-8f6d-40ce-9153-41873bc0d9ec.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027254.jpg_a83f385d-bb0b-43a4-9631-f24450b8b13d.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027254.jpg_b8f9469b-d31f-4c15-bcbc-2040fae65c92.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027254.jpg_c81ea6ad-def3-410d-a5d7-fe8b676e8606.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027254.jpg_d49c29f2-9f78-4308-8b98-6169610343ce.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027254.jpg_d6c90fda-33b6-474d-8aa8-0576fd7986e4.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027254.jpg_ff482a73-e3b4-4e94-aef2-e263010f8f13.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027334.jpg_06bb782b-78fb-4b41-bb37-7253384b214c.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027334.jpg_2b68ae20-6e36-4a79-b72e-4ae2f840dcc5.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027334.jpg_2f42bb23-bb84-4b75-81d8-a8079326981f.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027334.jpg_41743548-d195-44dd-9bfe-4463857df2d1.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027334.jpg_6b5e7a68-07b8-4e18-b68e-994ee808fde2.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027334.jpg_879a3f57-4b61-4b49-bfb6-9af9f92b2a09.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027334.jpg_93cf7ba9-328e-4c15-9705-4fc07e2ff25e.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027334.jpg_98581be8-705c-4653-916d-1727db2dd1f5.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027334.jpg_a175ccb5-6758-443e-a68b-54eba974f661.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027334.jpg_af6f576b-7de9-4d54-a973-e0cc32ab41bf.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0027447.jpg_5f79bee2-ada2-4510-bfbb-919a565765c1.jpg',
# ...
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024550.jpg_c7ec8790-eba1-422e-8b37-aed12c5c262f.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024564.jpg_36f5bb0f-42d7-4cad-acc0-e97ac939eb58.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024564.jpg_fbfed764-1e1b-4c47-9728-6e439f3aa1c9.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024573.jpg_1642ff42-ba3f-4f43-b734-a367ff37752b.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024595.jpg_f29ef5e8-da92-4676-9529-fe53ca98bda1.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024665.jpg_e56ba4ad-d358-49e8-b27d-e10bf43b4d53.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024666.jpg_7d50ae9f-5a22-4bde-bcfd-7ce4020ad3dd.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024666.jpg_83bb5bc4-8a3a-4702-b502-edf8553c8702.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024673.jpg_0440ff85-70a6-4d0e-8566-e7be0cee7693.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024673.jpg_48139ac4-6840-40c7-979d-52a050ef0b32.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024743.jpg_8e826de1-ed05-40ff-b6ec-fceff49c7b90.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024787.jpg_97767964-f957-4277-928a-46c6e136ec3d.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024795.jpg_f62ce46b-c92d-4924-b691-78b3766286da.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024829.jpg_39c2d450-a27d-47cc-9d82-fe14d4d2f029.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024833.jpg_01d32b65-71f9-4d74-9fa2-60398f9e3f4a.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024833.jpg_6496221d-07dd-476a-b2f4-abe6748be404.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024848.jpg_3be90727-2e35-46e8-8fef-9c9447862f7b.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024885.jpg_deb745b8-e34b-473e-86ad-b81d856f52e4.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024897.jpg_11ed97ca-da98-47a2-84d6-3ae2313987a5.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024984.jpg_a4b63c40-a436-43ff-89a7-7e1535b2afcd.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0024984.jpg_e4a5a5d0-1850-4d2e-9e85-4ceee60bc8cd.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025019.jpg_48227ef4-0e2b-4eb0-a382-2dcb841c710a.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025019.jpg_81ea52f1-6f6c-4766-80b8-b7aa3a79a8d4.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025046.jpg_80ad8441-50f6-459a-b396-db48ec24eeab.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025046.jpg_d11bd72c-2ec3-44de-8bc5-893165866bf5.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025102.jpg_3466a970-a240-449e-a808-55b07d0b6cde.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025102.jpg_395ed71c-1815-4000-840b-64ee960d4edb.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025102.jpg_6e0a6ef4-cee7-44e1-b3bd-99d7dc3a2d04.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025102.jpg_c7687029-dc66-4487-b503-2a6c59d329db.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025260.jpg_1942f7e6-309a-495d-83cb-a9f66b1e3399.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025260.jpg_4d667e49-7697-47c5-a46c-6ae886a1fba9.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025260.jpg_eb2395fd-c61f-48e4-b1ad-36389a012c1e.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025266.jpg_fc128f92-6b71-4b3c-a5f9-d097af655cd4.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025285.jpg_34b49c05-2e94-42e9-bde4-6e45912093d7.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025285.jpg_72ca0636-82e0-4e19-a7d9-ac73d6f0871d.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025299.jpg_0472d37a-dd99-4e1d-9e2d-4bd7f6179229.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025299.jpg_366ab95a-01b9-4ad0-a37f-454ff3ba356b.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025301.jpg_9751493c-8f45-40c4-b603-a888e1d14b56.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025322.jpg_ec2e9d35-188b-4b57-89cf-8e2ec22b04be.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025362.jpg_4851b912-7f37-402a-b01c-625ce3f3b4f6.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025383.jpg_fc5dc4af-fb98-4114-b041-d4166927989f.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025417.jpg_3be344b4-2880-4bf4-809b-9e0f97594657.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025433.jpg_0fa1204d-7b08-4a43-9e83-975e94ca4cf3.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025433.jpg_bbab2bce-4d3a-4748-822d-deee9dd38a97.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025433.jpg_df7895d0-ad80-470e-b6b2-1fded63291a6.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025467.jpg_1d46aeab-2df8-4487-af8e-3ed00d45ea82.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025467.jpg_8a5f18ff-735f-4a0d-9ffa-a2f42e45cfcc.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025509.jpg_7f9bc367-7b81-4fb3-91bf-8f1b20d03962.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025530.jpg_425c80be-82db-4199-8e0b-af1a60857605.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025530.jpg_70b896c9-b52c-41cd-8975-d7df74732f3a.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025530.jpg_c4eca364-8363-4d89-8da4-b59a358e7496.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025557.jpg_4bfde2e2-f28a-46e0-b2f8-e7b26a8fb26b.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025576.jpg_696531db-bf65-4392-90fe-de4c510ae5ae.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025576.jpg_d2aecf06-e8fa-46c5-ac1b-a785e41df995.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025617.jpg_4272f8f4-ea03-455c-8f60-05037380646f.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025617.jpg_6aa1bf07-63f3-4245-a892-f6f4afb23077.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025630.jpg_3636569c-7be6-4eff-9d1b-be04f702cf4b.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025630.jpg_99ebc9b3-ba3b-4f05-8463-4d6442686023.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025630.jpg_f291e199-a288-4650-8f42-ba6a4c3bdabe.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025644.jpg_f4b1688f-b36c-4509-91cc-e85bc9593b13.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025691.jpg_240ad471-5369-4a12-ac26-ebd4d8f731f5.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025700.jpg_f161f421-ae24-45f9-aaa7-2a0024929b82.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025700.jpg_f655fcd5-7cc1-4a2f-925e-aa249790e477.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025711.jpg_b0e1961b-8b7b-4ba4-9987-a2b0058b1ec9.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025718.jpg_848b791a-00e1-4529-accc-046247d2c954.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025731.jpg_0493b95f-b8b4-4772-8b84-e8231e9c1b1d.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025793.jpg_4ee8905f-48c9-4dfa-9d5f-d2a2b63bde6f.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025793.jpg_860da4e4-e4ae-40cf-a5cb-47339d92c9aa.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025793.jpg_8fff194c-68e3-4f2d-b616-a173c2797786.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025793.jpg_9935da7d-f70b-45bf-aef1-d7305aadca14.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025824.jpg_00cbd27a-4210-42c3-913f-b84262173e8f.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025824.jpg_1057cf4c-b7f0-4554-97bc-2aba7f2f2aed.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025824.jpg_9f458b04-db81-4ed9-96c1-af5e4b09e2d5.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025824.jpg_a49838af-58e9-4304-a4e5-7307ab66d9e5.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025824.jpg_f8bc76fe-5822-4629-813e-c640858cde8a.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025932.jpg_86765007-31f0-4e03-95e6-5c9144faff4d.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025932.jpg_b486d0b0-3b5b-455c-b193-f7005fd135f4.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025940.jpg_58cf43eb-8f43-4c47-a4b4-056c09c664d2.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025940.jpg_5bd7b19c-d8d7-4ab4-bf3b-035a3c362e83.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025971.jpg_ad6e4cdd-1375-4bd9-995b-3861a664d2d6.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025975.jpg_15e20836-ed28-432a-b8f8-6eb947dc4b1b.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0025975.jpg_248d96bc-5c9b-42e8-b840-5a394a617e9d.jpg',
#  'C:\\Users\\hp\\Downloads\\Python\\NN\\SkinCancer_ISIC_Dataset\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0026056.jpg_d5441465-0505-48a8-b65b-2f8b299c1bd4.jpg',
#  ...]

# %%
# get dataset with new columns appended in the dataframe/
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
#new_df = original_df.append(df2)
new_df = pd.concat([original_df, df2], ignore_index=True)

# %%
# View the  class count of each folders
new_df['Label'].value_counts()
# Out:
# Label
# actinic keratosis             528
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# dermatofibroma                 95
# seborrheic keratosis           77
# Name: count, dtype: int64

# %%
# set batch size and image size.
batch_size = 32
img_height = 180
img_width = 180

# %%
#Get the validation dataset from the train datset from the dataset of Train folder.
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training', ## Todo choose the correct parameter value, so that only training data is refered to
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 7153 files belonging to 9 classes.
# Using 5723 files for training.

# %%
#Get the validation dataset from the train datset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',## Todo choose the correct parameter value, so that only validation data is refered to,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 7153 files belonging to 9 classes.
# Using 1430 files for validation.

# %%
# Set autotune and cache for both train dataset and test dataset.
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

model = Sequential([
  #layers.experimental.preprocessing.Rescaling(1./255),
  layers.Rescaling(1./255, input_shape=(180, 180, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:18: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
## Compile the Model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Run with 20 epoch 
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 53s 243ms/step - accuracy: 0.2844 - loss: 1.8693 - val_accuracy: 0.4923 - val_loss: 1.3382
# Epoch 2/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 42s 234ms/step - accuracy: 0.5178 - loss: 1.2997 - val_accuracy: 0.6140 - val_loss: 1.1428
# Epoch 3/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 42s 235ms/step - accuracy: 0.6072 - loss: 1.1205 - val_accuracy: 0.6161 - val_loss: 1.1489
# Epoch 4/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 41s 230ms/step - accuracy: 0.6680 - loss: 0.9259 - val_accuracy: 0.6273 - val_loss: 1.0526
# Epoch 5/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 41s 229ms/step - accuracy: 0.7202 - loss: 0.7798 - val_accuracy: 0.6860 - val_loss: 0.8815
# Epoch 6/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 41s 231ms/step - accuracy: 0.7670 - loss: 0.6353 - val_accuracy: 0.7077 - val_loss: 0.8703
# Epoch 7/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 42s 233ms/step - accuracy: 0.8129 - loss: 0.5374 - val_accuracy: 0.7846 - val_loss: 0.7080
# Epoch 8/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 42s 232ms/step - accuracy: 0.8693 - loss: 0.3792 - val_accuracy: 0.7266 - val_loss: 0.8446
# Epoch 9/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 42s 235ms/step - accuracy: 0.8622 - loss: 0.3944 - val_accuracy: 0.7853 - val_loss: 0.7455
# Epoch 10/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 42s 236ms/step - accuracy: 0.8838 - loss: 0.3488 - val_accuracy: 0.8210 - val_loss: 0.6670
# Epoch 11/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 47s 264ms/step - accuracy: 0.8876 - loss: 0.3192 - val_accuracy: 0.7797 - val_loss: 0.7540
# Epoch 12/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 45s 251ms/step - accuracy: 0.9054 - loss: 0.2663 - val_accuracy: 0.8007 - val_loss: 0.7625
# Epoch 13/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 47s 262ms/step - accuracy: 0.9135 - loss: 0.2275 - val_accuracy: 0.8196 - val_loss: 0.7096
# Epoch 14/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 45s 254ms/step - accuracy: 0.9318 - loss: 0.1867 - val_accuracy: 0.8210 - val_loss: 0.7375
# Epoch 15/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 46s 256ms/step - accuracy: 0.9399 - loss: 0.1707 - val_accuracy: 0.8301 - val_loss: 0.6251
# Epoch 16/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 46s 255ms/step - accuracy: 0.9299 - loss: 0.1900 - val_accuracy: 0.8217 - val_loss: 0.7359
# Epoch 17/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 43s 241ms/step - accuracy: 0.9431 - loss: 0.1579 - val_accuracy: 0.8322 - val_loss: 0.7000
# Epoch 18/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 46s 257ms/step - accuracy: 0.9486 - loss: 0.1416 - val_accuracy: 0.8413 - val_loss: 0.7058
# Epoch 19/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 46s 258ms/step - accuracy: 0.9616 - loss: 0.1048 - val_accuracy: 0.8266 - val_loss: 0.7653
# Epoch 20/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 46s 255ms/step - accuracy: 0.9520 - loss: 0.1187 - val_accuracy: 0.8252 - val_loss: 0.7738

# %%
# VIsuallize the model accuracy result

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#CNN Model Architecture

#Sequential allows you to create models layer-by-layer  
model = Sequential()

#model.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer
# Rescaling Layer
model.add(layers.Rescaling(1./255, input_shape=(180, 180, 3)))

#First Convulation layer
model.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Second Convulation Layer
model.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Third Convulation Layer
model.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Dropout layer with 50% Fraction of the input units to drop.
model.add(layers.Dropout(0.5))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model.add(layers.Flatten())

#Dense Layer
model.add(layers.Dense(128,activation='relu'))

#Dropout layer with 25% Fraction of the input units to drop.
model.add(layers.Dropout(0.25))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model.add(layers.Dense(len(class_names),activation='softmax'))

model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_5 (Rescaling)         │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 178, 178, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 89, 89, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 87, 87, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 43, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 41, 41, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 20, 20, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 20, 20, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 51200)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 128)            │     6,553,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 9)              │         1,161 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,648,137 (25.36 MB)
#  Trainable params: 6,648,137 (25.36 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# vizualizing the model 
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# Compile the model ans set the Checkpoints and run with 20 epochs

# %%
# Train the model
#Compile the Model
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
#Adam optimization: is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments.
#categorical_crossentropy: Used as a loss function for multi-class classification model where there are two or more output labels.

#model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
#ModelCheckpoint callback is used in conjunction with training using model.fit() to save a model or weights (in a checkpoint file) at some interval,
#so the model or weights can be loaded later to continue the training from the state saved.
checkpoint = ModelCheckpoint("my_model1.keras",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)

#Stop training when a monitored metric has stopped improving.
earlystop = EarlyStopping(monitor="val_accuracy",patience=5,mode="auto",verbose=1)
# Train the model
epochs = 20
history = model.fit(train_ds, validation_data=val_ds, epochs=epochs,callbacks=[checkpoint,earlystop])
# Out:
# Epoch 1/20
# C:\Users\hp\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\nn.py:599: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - accuracy: 0.1844 - loss: 2.1360
# Epoch 1: val_accuracy improved from -inf to 0.38951, saving model to my_model1.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 106s 582ms/step - accuracy: 0.1849 - loss: 2.1348 - val_accuracy: 0.3895 - val_loss: 1.5919
# Epoch 2/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 0.4113 - loss: 1.5610
# Epoch 2: val_accuracy improved from 0.38951 to 0.52517, saving model to my_model1.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 108s 601ms/step - accuracy: 0.4114 - loss: 1.5607 - val_accuracy: 0.5252 - val_loss: 1.3395
# Epoch 3/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 608ms/step - accuracy: 0.4963 - loss: 1.3541
# Epoch 3: val_accuracy did not improve from 0.52517
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 115s 641ms/step - accuracy: 0.4963 - loss: 1.3540 - val_accuracy: 0.5154 - val_loss: 1.2967
# Epoch 4/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.5245 - loss: 1.2486
# Epoch 4: val_accuracy did not improve from 0.52517
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 120s 673ms/step - accuracy: 0.5245 - loss: 1.2486 - val_accuracy: 0.5105 - val_loss: 1.3752
# Epoch 5/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 677ms/step - accuracy: 0.5657 - loss: 1.1588
# Epoch 5: val_accuracy improved from 0.52517 to 0.59021, saving model to my_model1.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 129s 722ms/step - accuracy: 0.5658 - loss: 1.1587 - val_accuracy: 0.5902 - val_loss: 1.1266
# Epoch 6/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 627ms/step - accuracy: 0.6356 - loss: 1.0054
# Epoch 6: val_accuracy improved from 0.59021 to 0.64336, saving model to my_model1.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 118s 659ms/step - accuracy: 0.6356 - loss: 1.0055 - val_accuracy: 0.6434 - val_loss: 1.0102
# Epoch 7/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.6398 - loss: 0.9907
# Epoch 7: val_accuracy improved from 0.64336 to 0.67343, saving model to my_model1.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 102s 572ms/step - accuracy: 0.6398 - loss: 0.9905 - val_accuracy: 0.6734 - val_loss: 0.9144
# Epoch 8/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.6942 - loss: 0.8475
# Epoch 8: val_accuracy improved from 0.67343 to 0.70559, saving model to my_model1.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 98s 549ms/step - accuracy: 0.6942 - loss: 0.8475 - val_accuracy: 0.7056 - val_loss: 0.8491
# Epoch 9/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - accuracy: 0.7172 - loss: 0.7567
# Epoch 9: val_accuracy improved from 0.70559 to 0.73427, saving model to my_model1.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 102s 569ms/step - accuracy: 0.7172 - loss: 0.7568 - val_accuracy: 0.7343 - val_loss: 0.7868
# Epoch 10/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - accuracy: 0.7218 - loss: 0.7519
# Epoch 10: val_accuracy did not improve from 0.73427
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 106s 590ms/step - accuracy: 0.7218 - loss: 0.7519 - val_accuracy: 0.7196 - val_loss: 0.8205
# Epoch 11/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - accuracy: 0.7499 - loss: 0.6768
# Epoch 11: val_accuracy improved from 0.73427 to 0.75734, saving model to my_model1.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 108s 601ms/step - accuracy: 0.7499 - loss: 0.6767 - val_accuracy: 0.7573 - val_loss: 0.7264
# Epoch 12/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - accuracy: 0.7935 - loss: 0.5756
# Epoch 12: val_accuracy improved from 0.75734 to 0.76713, saving model to my_model1.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 100s 559ms/step - accuracy: 0.7934 - loss: 0.5758 - val_accuracy: 0.7671 - val_loss: 0.7231
# Epoch 13/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - accuracy: 0.7911 - loss: 0.5754
# Epoch 13: val_accuracy improved from 0.76713 to 0.80350, saving model to my_model1.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 99s 554ms/step - accuracy: 0.7911 - loss: 0.5754 - val_accuracy: 0.8035 - val_loss: 0.6375
# Epoch 14/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.8221 - loss: 0.5130
# Epoch 14: val_accuracy did not improve from 0.80350
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 97s 539ms/step - accuracy: 0.8221 - loss: 0.5131 - val_accuracy: 0.8000 - val_loss: 0.6649
# Epoch 15/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.8012 - loss: 0.5654
# Epoch 15: val_accuracy did not improve from 0.80350
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 106s 592ms/step - accuracy: 0.8012 - loss: 0.5653 - val_accuracy: 0.7909 - val_loss: 0.6741
# Epoch 16/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.8194 - loss: 0.4782
# Epoch 16: val_accuracy did not improve from 0.80350
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 102s 569ms/step - accuracy: 0.8194 - loss: 0.4783 - val_accuracy: 0.7476 - val_loss: 0.7612
# Epoch 17/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.8310 - loss: 0.4631
# Epoch 17: val_accuracy did not improve from 0.80350
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 98s 547ms/step - accuracy: 0.8309 - loss: 0.4632 - val_accuracy: 0.7895 - val_loss: 0.7163
# Epoch 18/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.8229 - loss: 0.4938
# Epoch 18: val_accuracy improved from 0.80350 to 0.81189, saving model to my_model1.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 99s 551ms/step - accuracy: 0.8230 - loss: 0.4935 - val_accuracy: 0.8119 - val_loss: 0.6436
# Epoch 19/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.8455 - loss: 0.4096
# Epoch 19: val_accuracy did not improve from 0.81189
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 98s 548ms/step - accuracy: 0.8455 - loss: 0.4096 - val_accuracy: 0.7986 - val_loss: 0.6398
# Epoch 20/20
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.8630 - loss: 0.3811
# Epoch 20: val_accuracy improved from 0.81189 to 0.84615, saving model to my_model1.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 98s 547ms/step - accuracy: 0.8630 - loss: 0.3811 - val_accuracy: 0.8462 - val_loss: 0.5555

# %%
### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

#epochs_range = range(epochs)
epochs_range = np.arange(len(acc))
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
from collections import Counter
# split into input and output elements
X, y = original_df['Path'], original_df['Label']
# label encode the target variable
y = LabelEncoder().fit_transform(y)
# summarize distribution
counter = Counter(y)
for k,v in counter.items():
	per = v / len(y) * 100
	print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
# plot the distribution
plt.bar(counter.keys(), counter.values())
plt.show()
# Out:
# Class=0, n=114 (5.092%)
# Class=1, n=376 (16.793%)
# Class=2, n=95 (4.243%)
# Class=3, n=438 (19.562%)
# Class=4, n=357 (15.945%)
# Class=5, n=462 (20.634%)
# Class=6, n=77 (3.439%)
# Class=7, n=181 (8.084%)
# Class=8, n=139 (6.208%)

# %%
#['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 
#'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 
#'vascular lesion']

# %%
7th number class has lowest samples
From the above array  "seborrheic keratosis" has the lowest samples.
Class=6, n=77 (3.439%)
# Out:
#   Cell In[66], line 1
#     7th number class has lowest samples
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='your_optimser',
              loss=your_loss_function_goes_here,
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# Your code goes here

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
history = ## your training code

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 class_names = train_ds.class_names
#       2 print(class_names)
#
# AttributeError: '_PrefetchDataset' object has no attribute 'class_names'

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
#['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma',
# 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis'
#, 'squamous cell carcinoma', 'vascular lesion']## Your code goes here.

# %%
Class=0, n=114 (5.092%)
Class=1, n=376 (16.793%)
Class=2, n=95 (4.243%)
Class=3, n=438 (19.562%)
Class=4, n=357 (15.945%)
Class=5, n=462 (20.634%)
Class=6, n=77 (3.439%)
Class=7, n=181 (8.084%)
Class=8, n=139 (6.208%)

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?

# %%
Which class has the least number of samples?
Class=6, n=77 (3.439%)

- Which classes dominate the data in terms proportionate number of samples?
Class=3, n=438 (19.562%)
Class=4, n=357 (15.945%)
Class=5, n=462 (20.634%)
Class=1, n=376 (16.793%)
total clases dominated by class 4,5,6,2 is 72.93%

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="To do"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)

# %%
new_df['Label'].value_counts()

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train="path to directory with training data + data created using augmentor"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = ## Todo choose the correct parameter value, so that only training data is refered to,,
  image_size=(img_height, img_width),
  batch_size=batch_size)

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = ## Todo choose the correct parameter value, so that only validation data is refered to,
  image_size=(img_height, img_width),
  batch_size=batch_size)

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 30
## Your code goes here, use 50 epochs.
history = # your model fit code

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %%
The score was very low when the layers used are with out Dropouts and Augmentor.
As they are included the accuracy of train dataset and validation dataset improved significantly.

Epoch 20: val_accuracy improved from 0.81189 to 0.84615, saving model to my_model1.keras
179/179 ━━━━━━━━━━━━━━━━━━━━ 98s 547ms/step - accuracy: 0.8630 - loss: 0.3811 - val_accuracy: 0.8462 - val_loss: 0.5555

# %%
import pickle

#model.save('full_model41.h5')
model.save('my_model4.keras')
    
# Load entire model
loaded_model = tf.keras.models.load_model('my_model4.keras')

# Save training history
with open('training_history4.pickle', 'wb') as file:
    pickle.dump(history.history, file)

# Load training history
with open('training_history4.pickle', 'rb') as file:
    loaded_history = pickle.load(file)

# %%
from glob import glob
from tensorflow.keras.preprocessing.image import load_img
Test_image_path = os.path.join(data_dir_test, class_names[1], '*')
Test_image = glob(Test_image_path)
Test_image = load_img(Test_image[-1],target_size=(180,180,3))
plt.imshow(Test_image)
plt.grid(False)

img = np.expand_dims(Test_image,axis=0)
pred = model.predict(img)
pred = np.argmax(pred)
pred_class = class_names[pred]
print("Actual Class "+ class_names[1] +'\n'+ "Predictive Class "+pred_class )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# Actual Class basal cell carcinoma
# Predictive Class squamous cell carcinoma

# %%
## END OF Assignment ##
